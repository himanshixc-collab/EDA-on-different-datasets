# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# #CSV

# %%
nf=pd.read_csv(r"C:\Users\Hianshi\Downloads\netflix_full.csv")
nf
# Out:
#             id   type                          name creator  \
# 0     81416533  Movie                Heart of Stone     NaN
# 1     80991406  Movie  Johnny English Strikes Again     NaN
# 2     81644420  Movie                          Hunt     NaN
# 3     70208104  Movie                    Safe House     NaN
# 4     70297761  Movie                    Commitment     NaN
# ...        ...    ...                           ...     ...
# 3251  70306646  Movie                         Creep     NaN
# 3252  81359795  Movie                          Irul     NaN
# 3253  81151880  Movie     Game Over (Hindi Version)     NaN
# 3254  81365135  Movie                          Love     NaN
# 3255  81036535  Movie                     Lang Tong     NaN
#
#                                               starring  year rating     time  \
# 0                  Gal Gadot, Jamie Dornan, Alia Bhatt  2023  TV-PG  125 min
# 1            Rowan Atkinson, Ben Miller, Emma Thompson  2018  TV-PG   88 min
# ...

# %%
nf.count()
# Out:
# id           3256
# type         3256
# name         3256
# creator       713
# starring     3256
# year         3256
# rating       3256
# time         3256
# genres       3255
# country      2974
# describle    3256
# dtype: int64

# %%
nf.head()
# Out:
#          id   type                          name creator  \
# 0  81416533  Movie                Heart of Stone     NaN
# 1  80991406  Movie  Johnny English Strikes Again     NaN
# 2  81644420  Movie                          Hunt     NaN
# 3  70208104  Movie                    Safe House     NaN
# 4  70297761  Movie                    Commitment     NaN
#
#                                          starring  year rating     time  \
# 0             Gal Gadot, Jamie Dornan, Alia Bhatt  2023  TV-PG  125 min
# 1       Rowan Atkinson, Ben Miller, Emma Thompson  2018  TV-PG   88 min
# 2       Lee Jung-jae, Jung Woo-sung, Jeon Hye-jin  2022  TV-14  125 min
# 3  Denzel Washington, Ryan Reynolds, Vera Farmiga  2012  TV-14  114 min
# 4        Choi Seung-hyun, Han Ye-ri, Yoon Je-moon  2013  TV-14  112 min
#
#                                               genres        country  \
# 0  Drama Movies ,Action & Adventure Movies ,Spy M...  United States
# ...

# %%
nf.tail()
# Out:
#             id   type                       name creator  \
# 3251  70306646  Movie                      Creep     NaN
# 3252  81359795  Movie                       Irul     NaN
# 3253  81151880  Movie  Game Over (Hindi Version)     NaN
# 3254  81365135  Movie                       Love     NaN
# 3255  81036535  Movie                  Lang Tong     NaN
#
#                                               starring  year rating    time  \
# 3251                       Mark Duplass, Patrick Brice  2014  TV-14  77 min
# 3252  Fahadh Faasil, Soubin Shahir, Darshana Rajendran  2021  TV-14  91 min
# 3253              Taapsee Pannu, Vinodhini, Parvathi T  2019  TV-MA  97 min
# 3254        Shine Tom Chacko, Rajisha Vijayan, Gokulan  2020  TV-14  91 min
# 3255     William Lawandi, Angeline Yap, Vivienne Tseng  2015  TV-MA  81 min
#
#                                                  genres        country  \
# 3251  Independent Movies ,Horror Movies ,Thriller Mo...  United States
# ...

# %%
nf.describe()
# Out:
#                  id         year
# count  3.256000e+03  3256.000000
# mean   8.063665e+07  2019.364865
# std    1.936469e+06     2.704297
# min    7.004527e+07  2012.000000
# 25%    8.021615e+07  2018.000000
# 50%    8.112197e+07  2020.000000
# 75%    8.141198e+07  2022.000000
# max    8.171850e+07  2023.000000

# %%
nf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3256 entries, 0 to 3255
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         3256 non-null   int64
#  1   type       3256 non-null   object
#  2   name       3256 non-null   object
#  3   creator    713 non-null    object
#  4   starring   3256 non-null   object
#  5   year       3256 non-null   int64
#  6   rating     3256 non-null   object
#  7   time       3256 non-null   object
#  8   genres     3255 non-null   object
#  9   country    2974 non-null   object
#  10  describle  3256 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 279.9+ KB

# %%
nf['name'].value_counts()
# Out:
# name
# Kingdom                             3
# Love                                2
# Fearless                            2
# Tunnel                              2
# Zom 100: Bucket List of the Dead    2
#                                    ..
# Arnold                              1
# Animal                              1
# McGREGOR FOREVER                    1
# Headspace Guide to Meditation       1
# Lang Tong                           1
# Name: count, Length: 3237, dtype: int64

# %%
(nf['name'].value_counts()).sort_values
# Out:
# <bound method Series.sort_values of name
# Kingdom                             3
# Love                                2
# Fearless                            2
# Tunnel                              2
# Zom 100: Bucket List of the Dead    2
#                                    ..
# Arnold                              1
# Animal                              1
# McGREGOR FOREVER                    1
# Headspace Guide to Meditation       1
# Lang Tong                           1
# Name: count, Length: 3237, dtype: int64>

# %%
(nf['name'].value_counts()).sort_values(ascending=False)
# Out:
# name
# Kingdom                      3
# Kakegurui                    2
# Love                         2
# The Stranger                 2
# Chosen                       2
#                             ..
# Unbridled                    1
# Creep                        1
# Irul                         1
# Game Over (Hindi Version)    1
# Lang Tong                    1
# Name: count, Length: 3237, dtype: int64

# %%
nf.sort_values(['name'])
# Out:
#             id     type                                 name creator  \
# 1830  81644889    Movie                                "Sr."     NaN
# 1451  81240831    Movie                               #Alive     NaN
# 2051  81260630    Movie                    #FriendButMarried     NaN
# 2050  81260637    Movie                  #FriendButMarried 2     NaN
# 1649  81092768    Movie                              #Selfie     NaN
# ...        ...      ...                                  ...     ...
# 1551  81357618    Movie                    ¡Que viva México!     NaN
# 611   81464005  TV Show             Ōoku: The Inner Chambers     NaN
# 578   80186926  TV Show  ​SAINT SEIYA: Knights of the Zodiac     NaN
# 600   81684733  TV Show                         【OSHI NO KO】     NaN
# 2207  81443939    Movie                                 레드슈즈     NaN
#
#                                             starring  year rating       time  \
# ...

# %%
nf.sort_values(['name','rating'])
# Out:
#             id     type                                 name creator  \
# 1830  81644889    Movie                                "Sr."     NaN
# 1451  81240831    Movie                               #Alive     NaN
# 2051  81260630    Movie                    #FriendButMarried     NaN
# 2050  81260637    Movie                  #FriendButMarried 2     NaN
# 1649  81092768    Movie                              #Selfie     NaN
# ...        ...      ...                                  ...     ...
# 1551  81357618    Movie                    ¡Que viva México!     NaN
# 611   81464005  TV Show             Ōoku: The Inner Chambers     NaN
# 578   80186926  TV Show  ​SAINT SEIYA: Knights of the Zodiac     NaN
# 600   81684733  TV Show                         【OSHI NO KO】     NaN
# 2207  81443939    Movie                                 레드슈즈     NaN
#
#                                             starring  year rating       time  \
# ...

# %%
nf.drop_duplicates(subset=['name'])
# Out:
#             id   type                          name creator  \
# 0     81416533  Movie                Heart of Stone     NaN
# 1     80991406  Movie  Johnny English Strikes Again     NaN
# 2     81644420  Movie                          Hunt     NaN
# 3     70208104  Movie                    Safe House     NaN
# 4     70297761  Movie                    Commitment     NaN
# ...        ...    ...                           ...     ...
# 3250  80209658  Movie                     Unbridled     NaN
# 3251  70306646  Movie                         Creep     NaN
# 3252  81359795  Movie                          Irul     NaN
# 3253  81151880  Movie     Game Over (Hindi Version)     NaN
# 3255  81036535  Movie                     Lang Tong     NaN
#
#                                               starring  year rating     time  \
# 0                  Gal Gadot, Jamie Dornan, Alia Bhatt  2023  TV-PG  125 min
# 1            Rowan Atkinson, Ben Miller, Emma Thompson  2018  TV-PG   88 min
# ...

# %%
nf.drop_duplicates(subset=['name','time']).shape
# Out:
# (3252, 11)

# %%
categories=nf.groupby('time') 
categories

# %%
len(nf)
# Out:
# 3256

# %%
len(categories)
# Out:
# 192

# %%
categories.size()
# Out:
# time
# 1 Season      1055
# 10 Seasons       1
# 10 min           1
# 100 min         37
# 101 min         37
#               ...
# 95 min          44
# 96 min          40
# 97 min          39
# 98 min          29
# 99 min          30
# Length: 192, dtype: int64

# %%
categories.first()
# Out:
#                   id     type                                   name  \
# time
# 1 Season    81435684  TV Show                                 Arcane
# 10 Seasons  70281312  TV Show                          The Blacklist
# 10 min      81555915    Movie  The Witcher Bestiary Season 1, Part 2
# 100 min     70266110    Movie                      Company of Heroes
# 101 min     81453003    Movie               How I Became a Superhero
# ...              ...      ...                                    ...
# 95 min      80236421    Movie                             Extinction
# 96 min      81439253    Movie            Mobile Suit Gundam Hathaway
# 97 min      81696792    Movie                               Bear Man
# 98 min      81557402    Movie                           Blood & Gold
# 99 min      81441310    Movie                        The Lost Dragod
#
#                               creator  \
# time
# 1 Season    Christian Linke, Alex Yee
# 10 Seasons              Jon Bokenkamp
# ...

# %%
nf.rename(columns={'starring':'actors'})
# Out:
#             id   type                          name creator  \
# 0     81416533  Movie                Heart of Stone     NaN
# 1     80991406  Movie  Johnny English Strikes Again     NaN
# 2     81644420  Movie                          Hunt     NaN
# 3     70208104  Movie                    Safe House     NaN
# 4     70297761  Movie                    Commitment     NaN
# ...        ...    ...                           ...     ...
# 3251  70306646  Movie                         Creep     NaN
# 3252  81359795  Movie                          Irul     NaN
# 3253  81151880  Movie     Game Over (Hindi Version)     NaN
# 3254  81365135  Movie                          Love     NaN
# 3255  81036535  Movie                     Lang Tong     NaN
#
#                                                 actors  year rating     time  \
# 0                  Gal Gadot, Jamie Dornan, Alia Bhatt  2023  TV-PG  125 min
# 1            Rowan Atkinson, Ben Miller, Emma Thompson  2018  TV-PG   88 min
# ...

# %% [markdown]
# #SEABORN

# %%
sns.relplot(data=nf,x='type',y='id',kind='scatter')

# %%
rt = nf.query("rating == 'TV-PG'")
sns.lineplot(data=rt, x="country", y="time")
# Out:
# <Axes: xlabel='country', ylabel='time'>

# %%
sns.displot(data=nf, x="rating")

# %%
sns.displot(data=nf, x="year",kind='kde')

# %%
sns.displot(data=nf, x="year", kde=True)

# %%
sns.histplot(data=nf, x="year")
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
sns.histplot(data=nf, y="year")
# Out:
# <Axes: xlabel='Count', ylabel='year'>

# %%
sns.histplot(data=nf, x="rating", bins=30)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
sns.kdeplot(data=nf, x="year")
# Out:
# <Axes: xlabel='year', ylabel='Density'>

# %%
sns.kdeplot(data=nf, y="year")
# Out:
# <Axes: xlabel='Density', ylabel='year'>

# %%
sns.kdeplot(data=nf)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=nf, x="year", hue="rating", multiple="stack")
# Out:
# <Axes: xlabel='year', ylabel='Density'>

# %%
sns.boxplot(x=nf["year"])
# Out:
# <Axes: xlabel='year'>

# %%
sns.boxplot(data=nf, x="year", y="rating", hue="type")
# Out:
# <Axes: xlabel='year', ylabel='rating'>

# %%
sns.violinplot(x=nf["year"])
# Out:
# <Axes: xlabel='year'>

# %%
sns.violinplot(data=nf, x="year", y="rating")
# Out:
# <Axes: xlabel='year', ylabel='rating'>

# %%
sns.violinplot(data=nf, x="year", y="rating", hue="type")
# Out:
# <Axes: xlabel='year', ylabel='rating'>

# %%
df=sns.barplot(nf, x="type", y="time" )

# %%
sns.barplot(nf, x="rating", y="year", hue="year", legend=False)
# Out:
# <Axes: xlabel='rating', ylabel='year'>

# %%
sns.countplot(nf, x="rating")
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
sns.countplot(nf, x="rating", hue="year")
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
sns.countplot(nf, x="rating", hue="year", stat="percent")
# Out:
# <Axes: xlabel='rating', ylabel='percent'>

# %%
nf.drop_duplicates(subset=['name'])
# Out:
#             id   type                          name creator  \
# 0     81416533  Movie                Heart of Stone     NaN
# 1     80991406  Movie  Johnny English Strikes Again     NaN
# 2     81644420  Movie                          Hunt     NaN
# 3     70208104  Movie                    Safe House     NaN
# 4     70297761  Movie                    Commitment     NaN
# ...        ...    ...                           ...     ...
# 3250  80209658  Movie                     Unbridled     NaN
# 3251  70306646  Movie                         Creep     NaN
# 3252  81359795  Movie                          Irul     NaN
# 3253  81151880  Movie     Game Over (Hindi Version)     NaN
# 3255  81036535  Movie                     Lang Tong     NaN
#
#                                               starring  year rating     time  \
# 0                  Gal Gadot, Jamie Dornan, Alia Bhatt  2023  TV-PG  125 min
# 1            Rowan Atkinson, Ben Miller, Emma Thompson  2018  TV-PG   88 min
# ...

# %%
df=nf.pivot_table(index="type", columns="rating", values="year")
sns.heatmap(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(df, annot=True)
# Out:
# <Axes: xlabel='rating', ylabel='type'>

# %%
sns.pairplot(nf)

# %%
sns.pairplot(nf, hue='type')
