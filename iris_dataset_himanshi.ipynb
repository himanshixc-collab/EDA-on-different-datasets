# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# CSV

# %%
iris=pd.read_csv(r"C:\Users\HP\Downloads\iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
iris.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
iris.tail
# Out:
# <bound method NDFrame.tail of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
iris.describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
iris.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
iris['sepal_width'].value_counts()
# Out:
# sepal_width
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: count, dtype: int64

# %%
(iris['sepal_width'].value_counts()).sort_values
# Out:
# <bound method Series.sort_values of sepal_width
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: count, dtype: int64>

# %%
(iris['sepal_width'].value_counts()).sort_values(ascending=False)
# Out:
# sepal_width
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: count, dtype: int64

# %%
iris.sort_values(['sepal_length'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
iris.sort_values(['sepal_length','petal_width'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
iris.drop_duplicates(subset=['sepal_length'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# 13            4.3          3.0           1.1          0.1      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
# 27            5.2          3.5           1.5          0.2      setosa
# ...

# %%
iris.drop_duplicates(subset=['sepal_length']).shape
# Out:
# (35, 5)

# %%
categories=iris.groupby('species') 
categories

# %%
len(iris)
# Out:
# 150

# %%
len(categories)
# Out:
# 3

# %%
categories.size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
categories.first()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.1          3.5           1.4          0.2
# versicolor           7.0          3.2           4.7          1.4
# virginica            6.3          3.3           6.0          2.5

# %%
iris.rename(columns={'sepal_length':'length_of_sepal'})
# Out:
#      length_of_sepal  sepal_width  petal_length  petal_width    species
# 0                5.1          3.5           1.4          0.2     setosa
# 1                4.9          3.0           1.4          0.2     setosa
# 2                4.7          3.2           1.3          0.2     setosa
# 3                4.6          3.1           1.5          0.2     setosa
# 4                5.0          3.6           1.4          0.2     setosa
# ..               ...          ...           ...          ...        ...
# 145              6.7          3.0           5.2          2.3  virginica
# 146              6.3          2.5           5.0          1.9  virginica
# 147              6.5          3.0           5.2          2.0  virginica
# 148              6.2          3.4           5.4          2.3  virginica
# 149              5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# SEABORN

# %%
sns.relplot(data=iris,x='sepal_width',y='sepal_length',kind='scatter')

# %%
petal = iris.query("petal_width == '0.2'")
sns.lineplot(data=iris, x="petal_width", y="petal_length")
# Out:
# <Axes: xlabel='petal_width', ylabel='petal_length'>

# %%
sns.displot(data=iris, x="sepal_length")

# %%
sns.displot(data=iris, x="sepal_width",kind='kde')

# %%
sns.displot(data=iris, x="petal_width", kde=True)

# %%
sns.histplot(data=iris, x="sepal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=iris, y="petal_length")
# Out:
# <Axes: xlabel='Count', ylabel='petal_length'>

# %%
sns.histplot(data=iris, x="petal_width", bins=30)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.kdeplot(data=iris, x="sepal_width")
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.kdeplot(data=iris, y="petal_width")
# Out:
# <Axes: xlabel='Density', ylabel='petal_width'>

# %%
sns.kdeplot(data=iris)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=iris, x="petal_length", hue="species", multiple="stack")
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.boxplot(x=iris["petal_length"])
# Out:
# <Axes: xlabel='petal_length'>

# %%
sns.boxplot(data=iris, x="sepal_width", y="petal_width", hue="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
sns.violinplot(x=iris["petal_length"])
# Out:
# <Axes: xlabel='petal_length'>

# %%
sns.violinplot(data=iris, x="species", y="sepal_length")
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(data=iris, x="petal_width", y="sepal_width", hue="species")
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_width'>

# %%
sns.barplot(iris, x="sepal_width", y="petal_width")
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
sns.barplot(iris, x="sepal_width", y="petal_width", hue="species", legend=False)
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
sns.countplot(iris, x="species")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.countplot(iris, x="petal_width", hue="species")
# Out:
# <Axes: xlabel='petal_width', ylabel='count'>

# %%
sns.countplot(iris, x="petal_width", hue="species", stat="percent")
# Out:
# <Axes: xlabel='petal_width', ylabel='percent'>

# %%
iris.drop_duplicates(subset=['petal_length'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# 13            4.3          3.0           1.1          0.1      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 22            4.6          3.6           1.0          0.2      setosa
# 24            4.8          3.4           1.9          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# ...

# %%
iris= sns.load_dataset("iris").pivot_table(index="sepal_length", columns="petal_width", values="petal_length")
sns.heatmap(iris)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(iris, annot=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_length'>

# %%
sns.pairplot(iris)
