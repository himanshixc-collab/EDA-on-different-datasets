# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# CSV

# %%
sd=pd.read_csv(r"C:\Users\HP\Downloads\Student_data.csv")
sd
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
sd.count()
# Out:
# school        395
# sex           395
# age           395
# address       395
# famsize       395
# Pstatus       395
# Medu          395
# Fedu          395
# Mjob          395
# Fjob          395
# reason        395
# guardian      395
# traveltime    395
# studytime     395
# failures      395
# schoolsup     395
# famsup        395
# paid          395
# activities    395
# nursery       395
# higher        395
# internet      395
# romantic      395
# famrel        395
# freetime      395
# goout         395
# Dalc          395
# Walc          395
# health        395
# absences      395
# G1            395
# G2            395
# G3            395
# dtype: int64

# %%
sd.head
# Out:
# <bound method NDFrame.head of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
sd.tail
# Out:
# <bound method NDFrame.tail of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
sd.describe
# Out:
# <bound method NDFrame.describe of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
sd.info
# Out:
# <bound method DataFrame.info of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
sd['famrel'].value_counts()
# Out:
# famrel
# 4    195
# 5    106
# 3     68
# 2     18
# 1      8
# Name: count, dtype: int64

# %%
(sd['famrel'].value_counts()).sort_values
# Out:
# <bound method Series.sort_values of famrel
# 4    195
# 5    106
# 3     68
# 2     18
# 1      8
# Name: count, dtype: int64>

# %%
(sd['famrel'].value_counts()).sort_values(ascending=False)
# Out:
# famrel
# 4    195
# 5    106
# 3     68
# 2     18
# 1      8
# Name: count, dtype: int64

# %%
sd.sort_values(['freetime'])
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 111     GP   F   16       R     GT3       T     3     3  services     other
# 19      GP   M   16       U     LE3       T     4     3    health     other
# 260     GP   F   18       U     GT3       T     4     3  services     other
# 95      GP   F   15       R     GT3       T     1     1   at_home     other
# 301     GP   M   17       U     LE3       T     4     4     other   teacher
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 237     GP   F   16       U     GT3       T     2     1     other     other
# 18      GP   M   17       U     GT3       T     3     2  services  services
# 199     GP   F   16       U     LE3       T     4     4   teacher   teacher
# 308     GP   M   19       R     GT3       T     3     3     other  services
# 35      GP   F   15       U     GT3       T     2     3     other     other
#
# ...

# %%
sd.sort_values(['famrel','freetime'])
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 25      GP   F   16       U     GT3       T     2     2  services  services
# 184     GP   F   16       U     GT3       T     3     2     other     other
# 357     MS   F   17       U     LE3       A     3     2  services     other
# 66      GP   M   15       U     GT3       A     4     4     other  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 125     GP   M   15       U     GT3       T     3     4  services  services
# 239     GP   M   18       U     GT3       T     2     2     other  services
# 306     GP   M   20       U     GT3       A     3     2  services     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
#
# ...

# %%
sd.drop_duplicates(subset=['famrel'])
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1      GP   F   17       U     GT3       T     1     1   at_home     other
# 3      GP   F   15       U     GT3       T     4     2    health  services
# 25     GP   F   16       U     GT3       T     2     2  services  services
# 27     GP   M   15       U     GT3       T     4     2    health  services
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0   ...      4        3      4     1     1      3        6   5   6   6
# 1   ...      5        3      3     1     1      3        4   5   5   6
# 3   ...      3        2      2     1     1      5        2  15  14  15
# 25  ...      1        2      2     1     3      5       14   6   9   8
# 27  ...      2        2      4     2     4      1        4  15  16  15
#
# [5 rows x 33 columns]

# %%
sd.drop_duplicates(subset=['famrel']).shape
# Out:
# (5, 33)

# %%
categories=sd.groupby('famrel') 
categories

# %%
len(sd)
# Out:
# 395

# %%
len(categories)
# Out:
# 5

# %%
categories.size()
# Out:
# famrel
# 1      8
# 2     18
# 3     68
# 4    195
# 5    106
# dtype: int64

# %%
categories.first()
# Out:
#        school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# famrel
# 1          GP   F   16       U     GT3       T     2     2  services
# 2          GP   M   15       U     GT3       T     4     2    health
# 3          GP   F   15       U     GT3       T     4     2    health
# 4          GP   F   18       U     GT3       A     4     4   at_home
# 5          GP   F   17       U     GT3       T     1     1   at_home
#
#             Fjob  ... romantic freetime  goout  Dalc  Walc health absences  \
# famrel            ...
# 1       services  ...       no        2      2     1     3      5       14
# 2       services  ...       no        2      4     2     4      1        4
# 3       services  ...      yes        2      2     1     1      5        2
# 4        teacher  ...       no        3      4     1     1      3        6
# 5          other  ...       no        3      3     1     1      3        4
#
#         G1  G2  G3
# famrel
# 1        6   9   8
# ...

# %%
sd.rename(columns={'freetime':'whitespace'})
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# SEABORN

# %%
sns.relplot(data=sd,x='famrel',y='age',kind='scatter')

# %%
age = sd.query("age == '18'")
sns.lineplot(data=sd, x="famrel", y="health")
# Out:
# <Axes: xlabel='famrel', ylabel='health'>

# %%
sns.displot(data=sd, x="age")

# %%
sns.displot(data=sd, x="freetime",kind='kde')

# %%
sns.displot(data=sd, x="freetime", kde=True)

# %%
sns.histplot(data=sd, x="freetime")
# Out:
# <Axes: xlabel='freetime', ylabel='Count'>

# %%
sns.histplot(data=sd, y="age")
# Out:
# <Axes: xlabel='Count', ylabel='age'>

# %%
sns.histplot(data=sd, x="health", bins=30)
# Out:
# <Axes: xlabel='health', ylabel='Count'>

# %%
sns.kdeplot(data=sd, x="Fedu")
# Out:
# <Axes: xlabel='Fedu', ylabel='Density'>

# %%
sns.kdeplot(data=sd, y="Medu")
# Out:
# <Axes: xlabel='Density', ylabel='Medu'>

# %%
sns.kdeplot(data=sd)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=sd, x="age", hue="sex", multiple="stack")
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.boxplot(x=sd["age"])
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(data=sd, x="Fedu", y="Medu", hue="school")
# Out:
# <Axes: xlabel='Fedu', ylabel='Medu'>

# %%
sns.violinplot(x=sd["health"])
# Out:
# <Axes: xlabel='health'>

# %%
sns.violinplot(data=sd, x="freetime", y="age")
# Out:
# <Axes: xlabel='freetime', ylabel='age'>

# %%
sns.violinplot(data=sd, x="sex", y="Fedu", hue="address")
# Out:
# <Axes: xlabel='sex', ylabel='Fedu'>

# %%
sns.barplot(sd, x="address", y="Fedu")
# Out:
# <Axes: xlabel='address', ylabel='Fedu'>

# %%
sns.barplot(sd, x="address", y="age", hue="sex", legend=False)
# Out:
# <Axes: xlabel='address', ylabel='age'>

# %%
sns.countplot(sd, x="school")
# Out:
# <Axes: xlabel='school', ylabel='count'>

# %%
sns.countplot(sd, x="health", hue="school")
# Out:
# <Axes: xlabel='health', ylabel='count'>

# %%
sns.countplot(sd, x="school", hue="sex", stat="percent")
# Out:
# <Axes: xlabel='school', ylabel='percent'>

# %%
sd.drop_duplicates(subset=['famrel'])
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1      GP   F   17       U     GT3       T     1     1   at_home     other
# 3      GP   F   15       U     GT3       T     4     2    health  services
# 25     GP   F   16       U     GT3       T     2     2  services  services
# 27     GP   M   15       U     GT3       T     4     2    health  services
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0   ...      4        3      4     1     1      3        6   5   6   6
# 1   ...      5        3      3     1     1      3        4   5   5   6
# 3   ...      3        2      2     1     1      5        2  15  14  15
# 25  ...      1        2      2     1     3      5       14   6   9   8
# 27  ...      2        2      4     2     4      1        4  15  16  15
#
# [5 rows x 33 columns]

# %%
heat=sd.pivot_table(index="Fedu", columns="Medu", values="freetime")
sns.heatmap(heat)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(heat, annot=True)
# Out:
# <Axes: xlabel='Medu', ylabel='Fedu'>

# %%
sns.pairplot(sd)

# %%
sns.pairplot(sd, hue='address')
