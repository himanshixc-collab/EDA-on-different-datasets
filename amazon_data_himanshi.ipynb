# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# #CSV

# %%
az=pd.read_csv(r"C:\Users\Hianshi\Downloads\amz_rev.csv")
az
# Out:
#                         id       asins   brand  \
# 0     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 1     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 2     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 3     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 4     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# ...                    ...         ...     ...
# 1592  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1593  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1594  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1595  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1596  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
#
#                                              categories colors  \
# 0                            Amazon Devices,mazon.co.uk    NaN
# 1                            Amazon Devices,mazon.co.uk    NaN
# 2                            Amazon Devices,mazon.co.uk    NaN
# 3                            Amazon Devices,mazon.co.uk    NaN
# 4                            Amazon Devices,mazon.co.uk    NaN
# ...

# %%
az.count()
# Out:
# id                      1597
# asins                   1597
# brand                   1597
# categories              1597
# colors                   774
# dateAdded               1597
# dateUpdated             1597
# dimension                565
# ean                      898
# keys                    1597
# manufacturer             965
# manufacturerNumber       902
# name                    1597
# prices                  1597
# reviews.date            1217
# reviews.doRecommend      539
# reviews.numHelpful       900
# reviews.rating          1177
# reviews.sourceURLs      1597
# reviews.text            1597
# reviews.title           1580
# reviews.userCity           0
# reviews.userProvince       0
# reviews.username        1580
# sizes                      0
# upc                      898
# weight                   686
# dtype: int64

# %%
az.head()
# Out:
#                      id       asins   brand                  categories  \
# 0  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 1  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 2  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 3  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 4  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
#
#   colors             dateAdded           dateUpdated  \
# 0    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 1    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 2    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 3    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 4    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
#
#                   dimension  ean                         keys  ...  \
# 0  169 mm x 117 mm x 9.1 mm  NaN  kindlepaperwhite/b00qjdu3ky  ...
# 1  169 mm x 117 mm x 9.1 mm  NaN  kindlepaperwhite/b00qjdu3ky  ...
# ...

# %%
az.tail()
# Out:
#                         id       asins   brand  \
# 1592  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1593  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1594  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1595  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1596  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
#
#                                              categories colors  \
# 1592  Amazon Devices & Accessories,Amazon Device Acc...    NaN
# 1593  Amazon Devices & Accessories,Amazon Device Acc...    NaN
# 1594  Amazon Devices & Accessories,Amazon Device Acc...    NaN
# 1595  Amazon Devices & Accessories,Amazon Device Acc...    NaN
# 1596  Amazon Devices & Accessories,Amazon Device Acc...    NaN
#
#                  dateAdded           dateUpdated dimension  ean  \
# 1592  2016-04-02T14:40:43Z  2017-08-13T08:28:46Z       NaN  NaN
# 1593  2016-04-02T14:40:43Z  2017-08-13T08:28:46Z       NaN  NaN
# 1594  2016-04-02T14:40:43Z  2017-08-13T08:28:46Z       NaN  NaN
# ...

# %%
az.describe()
# Out:
#                 ean  reviews.numHelpful  reviews.rating  reviews.userCity  \
# count  8.980000e+02          900.000000     1177.000000               0.0
# mean   8.443135e+11           83.584444        4.359388               NaN
# std    3.416444e+09          197.150238        1.021445               NaN
# min    8.416670e+11            0.000000        1.000000               NaN
# 25%    8.416670e+11            0.000000        4.000000               NaN
# 50%    8.416670e+11            0.000000        5.000000               NaN
# 75%    8.487190e+11           34.000000        5.000000               NaN
# max    8.487190e+11          997.000000        5.000000               NaN
#
#        reviews.userProvince  sizes           upc
# count                   0.0    0.0  8.980000e+02
# mean                    NaN    NaN  8.443135e+11
# std                     NaN    NaN  3.416444e+09
# min                     NaN    NaN  8.416670e+11
# 25%                     NaN    NaN  8.416670e+11
# ...

# %%
az.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1597 entries, 0 to 1596
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1597 non-null   object
#  1   asins                 1597 non-null   object
#  2   brand                 1597 non-null   object
#  3   categories            1597 non-null   object
#  4   colors                774 non-null    object
#  5   dateAdded             1597 non-null   object
#  6   dateUpdated           1597 non-null   object
#  7   dimension             565 non-null    object
#  8   ean                   898 non-null    float64
#  9   keys                  1597 non-null   object
#  10  manufacturer          965 non-null    object
#  11  manufacturerNumber    902 non-null    object
#  12  name                  1597 non-null   object
#  13  prices                1597 non-null   object
#  14  reviews.date          1217 non-null   object
# ...

# %%
az['reviews.title'].value_counts()
# Out:
# reviews.title
# Great product                                                                                                                                                         16
# Five Stars                                                                                                                                                            14
# Great upgrade for aesthetics                                                                                                                                          10
# Great                                                                                                                                                                  9
# Love it                                                                                                                                                                8
# ...

# %%
(az['reviews.title'].value_counts()).sort_values
# Out:
# <bound method Series.sort_values of reviews.title
# Great product                                                                                                                                                         16
# Five Stars                                                                                                                                                            14
# Great upgrade for aesthetics                                                                                                                                          10
# Great                                                                                                                                                                  9
# Love it                                                                                                                                                                8
# ...

# %%
(az['reviews.title'].value_counts()).sort_values(ascending=False)
# Out:
# reviews.title
# Great product                                                                                                                                 16
# Five Stars                                                                                                                                    14
# Great upgrade for aesthetics                                                                                                                  10
# Great                                                                                                                                          9
# Love it                                                                                                                                        8
#                                                                                                                                               ..
# ...

# %%
az.sort_values(['reviews.title'])
# Out:
#                         id                                              asins  \
# 439   AVpfLiCSilAPnD_xWpk_                                         B00CX5P8FC
# 492   AVzRloqLGV-KLJ3aavBd                                         B07194GPJV
# 1580  AVpfODXeilAPnD_xXeUd                                         B00LORGAG6
# 416   AVpfLiCSilAPnD_xWpk_                                         B00CX5P8FC
# 467   AVsRjfwAU2_QcyX9PHqe                                         B01J2G4VBG
# ...                    ...                                                ...
# 810   AVpe7LD5LJeJML43ybWA  B00DOPNO4M,B00BWYQ9YE,B00CYQPMJC,B00CUU1CGY,B0...
# 812   AVpe7LD5LJeJML43ybWA  B00DOPNO4M,B00BWYQ9YE,B00CYQPMJC,B00CUU1CGY,B0...
# 815   AVpe7LD5LJeJML43ybWA  B00DOPNO4M,B00BWYQ9YE,B00CYQPMJC,B00CUU1CGY,B0...
# 816   AVpe7LD5LJeJML43ybWA  B00DOPNO4M,B00BWYQ9YE,B00CYQPMJC,B00CUU1CGY,B0...
# 819   AVpe7LD5LJeJML43ybWA  B00DOPNO4M,B00BWYQ9YE,B00CYQPMJC,B00CUU1CGY,B0...
#
# ...

# %%
az.sort_values(['reviews.title','reviews.text'])
# Out:
#                         id                                              asins  \
# 439   AVpfLiCSilAPnD_xWpk_                                         B00CX5P8FC
# 492   AVzRloqLGV-KLJ3aavBd                                         B07194GPJV
# 1580  AVpfODXeilAPnD_xXeUd                                         B00LORGAG6
# 416   AVpfLiCSilAPnD_xWpk_                                         B00CX5P8FC
# 467   AVsRjfwAU2_QcyX9PHqe                                         B01J2G4VBG
# ...                    ...                                                ...
# 816   AVpe7LD5LJeJML43ybWA  B00DOPNO4M,B00BWYQ9YE,B00CYQPMJC,B00CUU1CGY,B0...
# 810   AVpe7LD5LJeJML43ybWA  B00DOPNO4M,B00BWYQ9YE,B00CYQPMJC,B00CUU1CGY,B0...
# 806   AVpe7LD5LJeJML43ybWA  B00DOPNO4M,B00BWYQ9YE,B00CYQPMJC,B00CUU1CGY,B0...
# 796   AVpe7LD5LJeJML43ybWA  B00DOPNO4M,B00BWYQ9YE,B00CYQPMJC,B00CUU1CGY,B0...
# 794   AVpe7LD5LJeJML43ybWA  B00DOPNO4M,B00BWYQ9YE,B00CYQPMJC,B00CUU1CGY,B0...
#
# ...

# %%
az.drop_duplicates(subset=['weight'])
# Out:
#                         id       asins   brand  \
# 0     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 23    AVpfBEWcilAPnD_xTGb7  B002Y27P3M  Amazon
# 55    AVpff7_VilAPnD_xc1E_  B00DU15MU4  Amazon
# 454   AVsRjfwAU2_QcyX9PHqe  B01J2G4VBG  Amazon
# 852   AVpfpK8KLJeJML43BCuD  B01BH83OOM  Amazon
# 1394  AVph_N4z1cnluZ0-IkrF  B00K5W9WZW   Moshi
# 1406  AVsRilrqnnc1JgDc34jd  B01E9AHU8Q  Amazon
# 1413  AVpgKkzMLJeJML43J5BV  B01HC1S9HU  Amazon
# 1425  AVzRlqklGV-KLJ3aavB0  B01HC1S9HU  Amazon
# 1568  AVpfODXeilAPnD_xXeUd  B00LORGAG6  Amazon
#
#                                              categories colors  \
# 0                            Amazon Devices,mazon.co.uk    NaN
# 23              Kindle Store,Amazon Devices,Electronics    NaN
# 55    Categories,Amazon Devices,Streaming Media Players    NaN
# 454   Amazon Devices & Accessories,Amazon Device Acc...    NaN
# 852   Amazon Devices,Home,Smart Home & Connected Liv...  Black
# ...

# %%
az.drop_duplicates(subset=['weight','reviews.title']).shape
# Out:
# (1288, 27)

# %%
categories=az.groupby('weight') 
categories

# %%
len(az)
# Out:
# 1597

# %%
len(categories)
# Out:
# 9

# %%
categories.size()
# Out:
# weight
# 0.8 ounces     12
# 1.1 pounds     32
# 1.6 ounces     19
# 1.75 lbs      542
# 2.4 ounces     17
# 205 grams      23
# 4 ounces       19
# 4.6 ounces     10
# 5 ounces       12
# dtype: int64

# %%
categories.first()
# Out:
#                               id       asins   brand  \
# weight
# 0.8 ounces  AVph_N4z1cnluZ0-IkrF  B00K5W9WZW   Moshi
# 1.1 pounds  AVpfBEWcilAPnD_xTGb7  B002Y27P3M  Amazon
# 1.6 ounces  AVsRjfwAU2_QcyX9PHqe  B01J2G4VBG  Amazon
# 1.75 lbs    AVpfpK8KLJeJML43BCuD  B01BH83OOM  Amazon
# 2.4 ounces  AVpfODXeilAPnD_xXeUd  B00LORGAG6  Amazon
# 205 grams   AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 4 ounces    AVsRilrqnnc1JgDc34jd  B01E9AHU8Q  Amazon
# 4.6 ounces  AVzRlqklGV-KLJ3aavB0  B01HC1S9HU  Amazon
# 5 ounces    AVpgKkzMLJeJML43J5BV  B01HC1S9HU  Amazon
#
#                                                    categories colors  \
# weight
# 0.8 ounces  Cell Phones & Accessories,Accessories,Screen P...  Clear
# 1.1 pounds            Kindle Store,Amazon Devices,Electronics   None
# 1.6 ounces  Amazon Devices & Accessories,Amazon Device Acc...   None
# 1.75 lbs    Amazon Devices,Home,Smart Home & Connected Liv...  Black
# ...

# %%
az.rename(columns={'reviews.username':'name'})
# Out:
#                         id       asins   brand  \
# 0     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 1     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 2     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 3     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 4     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# ...                    ...         ...     ...
# 1592  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1593  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1594  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1595  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1596  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
#
#                                              categories colors  \
# 0                            Amazon Devices,mazon.co.uk    NaN
# 1                            Amazon Devices,mazon.co.uk    NaN
# 2                            Amazon Devices,mazon.co.uk    NaN
# 3                            Amazon Devices,mazon.co.uk    NaN
# 4                            Amazon Devices,mazon.co.uk    NaN
# ...

# %% [markdown]
# #SEABORN

# %%
sns.relplot(data=az,x='dimension',y='weight',kind='scatter')

# %%
ds = az.query("name == 'Ricky'")
sns.lineplot(data=az, x="dimension", y="reviews.rating")
# Out:
# <Axes: xlabel='dimension', ylabel='reviews.rating'>

# %%
sns.displot(data=az, x="weight")

# %%
sns.displot(data=az, x="reviews.rating",kind='kde')

# %%
sns.displot(data=az, x="reviews.rating", kde=True)

# %%
sns.histplot(data=az, x="dimension")
# Out:
# <Axes: xlabel='dimension', ylabel='Count'>

# %%
sns.histplot(data=az, y="weight")
# Out:
# <Axes: xlabel='Count', ylabel='weight'>

# %%
sns.histplot(data=az, x="weight", bins=30)
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %%
sns.kdeplot(data=az, x="reviews.rating")
# Out:
# <Axes: xlabel='reviews.rating', ylabel='Density'>

# %%
sns.kdeplot(data=az, y="reviews.rating")
# Out:
# <Axes: xlabel='Density', ylabel='reviews.rating'>

# %%
sns.kdeplot(data=az)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=az, x="reviews.rating", hue="dimension", multiple="stack")
# Out:
# <Axes: xlabel='reviews.rating', ylabel='Density'>

# %%
sns.boxplot(x=az["reviews.rating"])
# Out:
# <Axes: xlabel='reviews.rating'>

# %%
sns.boxplot(data=az, x="reviews.rating", y="weight", hue="dimension")
# Out:
# <Axes: xlabel='reviews.rating', ylabel='weight'>

# %%
sns.violinplot(x=az["reviews.rating"])
# Out:
# <Axes: xlabel='reviews.rating'>

# %%
sns.violinplot(data=az, x="reviews.rating", y="weight")
# Out:
# <Axes: xlabel='reviews.rating', ylabel='weight'>

# %%
sns.violinplot(data=az, x="weight", y="reviews.rating", hue="dimension")
# Out:
# <Axes: xlabel='weight', ylabel='reviews.rating'>

# %%
sns.barplot(az, x="dimension", y="weight")
# Out:
# <Axes: xlabel='dimension', ylabel='weight'>

# %%
sns.barplot(az, x="weight", y="reviews.rating", hue="dimension", legend=False)
# Out:
# <Axes: xlabel='weight', ylabel='reviews.rating'>

# %%
sns.countplot(az, x="reviews.rating")
# Out:
# <Axes: xlabel='reviews.rating', ylabel='count'>

# %%
sns.countplot(az, x="reviews.rating", hue="dimension")
# Out:
# <Axes: xlabel='reviews.rating', ylabel='count'>

# %%
sns.countplot(az, x="reviews.rating", hue="dimension", stat="percent")
# Out:
# <Axes: xlabel='reviews.rating', ylabel='percent'>

# %%
az.drop_duplicates(subset=['name'])
# Out:
#                         id       asins   brand  \
# 0     AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 23    AVpfBEWcilAPnD_xTGb7  B002Y27P3M  Amazon
# 55    AVpff7_VilAPnD_xc1E_  B00DU15MU4  Amazon
# 93    AV00lzP7GV-KLJ3ac0uk  B01LW1MS9C  Amazon
# 103   AV1T0_7M-jtxr-f31CoX  B01FWSVGQQ  Amazon
# ...                    ...         ...     ...
# 1413  AVpgKkzMLJeJML43J5BV  B01HC1S9HU  Amazon
# 1425  AVzRlqklGV-KLJ3aavB0  B01HC1S9HU  Amazon
# 1435  AVpge-anilAPnD_xtDVf  B00HX0SRXW  Amazon
# 1568  AVpfODXeilAPnD_xXeUd  B00LORGAG6  Amazon
# 1585  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
#
#                                              categories colors  \
# 0                            Amazon Devices,mazon.co.uk    NaN
# 23              Kindle Store,Amazon Devices,Electronics    NaN
# 55    Categories,Amazon Devices,Streaming Media Players    NaN
# 93                                       Amazon Devices    NaN
# 103                                      Amazon Devices    NaN
# ...

# %%
heat= az.pivot_table(index="weight", columns="categories", values="reviews.rating")
sns.heatmap(heat)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(heat, annot=True)
# Out:
# <Axes: xlabel='categories', ylabel='weight'>

# %%
sns.pairplot(data=az)

# %%
sns.pairplot(az , hue='dimension')
