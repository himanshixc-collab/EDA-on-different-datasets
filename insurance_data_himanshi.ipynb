# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# #CSV

# %%
ins=pd.read_csv(r"C:\Users\Hianshi\Downloads\insurance.csv")
ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
ins.count()
# Out:
# age         1338
# sex         1338
# bmi         1338
# children    1338
# smoker      1338
# region      1338
# charges     1338
# dtype: int64

# %%
ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
ins.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
ins.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
ins['age'].value_counts()
# Out:
# age
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64

# %%
(ins['age'].value_counts()).sort_values
# Out:
# <bound method Series.sort_values of age
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64>

# %%
(ins['age'].value_counts()).sort_values(ascending=False)
# Out:
# age
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 24    28
# 23    28
# 27    28
# 28    28
# 25    28
# 54    28
# 26    28
# 21    28
# 53    28
# 49    28
# 22    28
# 42    27
# 40    27
# 31    27
# 44    27
# 30    27
# 41    27
# 43    27
# 29    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 38    25
# 39    25
# 35    25
# 59    25
# 36    25
# 58    25
# 37    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64

# %%
ins.sort_values(['age'])
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1248   18  female  39.820         0     no  southeast   1633.96180
# 482    18  female  31.350         0     no  southeast   1622.18850
# 492    18  female  25.080         0     no  northeast   2196.47320
# 525    18  female  33.880         0     no  southeast  11482.63485
# 529    18    male  25.460         0     no  northeast   1708.00140
# ...   ...     ...     ...       ...    ...        ...          ...
# 398    64    male  25.600         2     no  southwest  14988.43200
# 335    64    male  34.500         0     no  southwest  13822.80300
# 378    64  female  30.115         3     no  northwest  16455.70785
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 635    64    male  38.190         0     no  northeast  14410.93210
#
# [1338 rows x 7 columns]

# %%
ins.sort_values(['age','children'])
# Out:
#       age     sex     bmi  children smoker     region      charges
# 22     18    male  34.100         0     no  southeast   1137.01100
# 31     18  female  26.315         0     no  northeast   2198.18985
# 50     18  female  35.625         0     no  northeast   2211.13075
# 102    18  female  30.115         0     no  northeast  21344.84670
# 121    18    male  23.750         0     no  northeast   1705.62450
# ...   ...     ...     ...       ...    ...        ...          ...
# 398    64    male  25.600         2     no  southwest  14988.43200
# 825    64  female  31.825         2     no  northeast  16069.08475
# 1241   64    male  36.960         2    yes  southeast  49577.66240
# 378    64  female  30.115         3     no  northwest  16455.70785
# 603    64  female  39.050         3     no  southeast  16085.12750
#
# [1338 rows x 7 columns]

# %%
ins.drop_duplicates(subset=['charges'])
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
ins.drop_duplicates(subset=['age','children']).shape
# Out:
# (219, 7)

# %%
categories=ins.groupby('age') 
categories

# %%
len(ins)
# Out:
# 1338

# %%
len(categories)
# Out:
# 47

# %%
categories.size()
# Out:
# age
# 18    69
# 19    68
# 20    29
# 21    28
# 22    28
# 23    28
# 24    28
# 25    28
# 26    28
# 27    28
# 28    28
# 29    27
# 30    27
# 31    27
# 32    26
# 33    26
# 34    26
# 35    25
# 36    25
# 37    25
# 38    25
# 39    25
# 40    27
# 41    27
# 42    27
# 43    27
# 44    27
# 45    29
# 46    29
# 47    29
# 48    29
# 49    28
# 50    29
# 51    29
# 52    29
# 53    28
# 54    28
# 55    26
# 56    26
# 57    26
# 58    25
# 59    25
# 60    23
# 61    23
# 62    23
# 63    23
# 64    22
# dtype: int64

# %%
categories.first()
# Out:
#         sex     bmi  children smoker     region      charges
# age
# 18     male  33.770         1     no  southeast   1725.55230
# 19   female  27.900         0    yes  southwest  16884.92400
# 20   female  22.420         0    yes  northwest  14711.74380
# 21   female  33.630         2     no  northwest   3579.82870
# 22     male  35.600         0    yes  southwest  35585.57600
# 23     male  34.400         0     no  southwest   1826.84300
# 24   female  26.600         0     no  northeast   3046.06200
# 25     male  26.220         0     no  northeast   2721.32080
# 26     male  20.800         0     no  southwest   2302.30000
# 27     male  42.130         0    yes  southeast  39611.75770
# 28     male  33.000         3     no  southeast   4449.46200
# 29   female  29.590         1     no  southeast   3947.41310
# 30     male  35.300         0    yes  southwest  36837.46700
# 31   female  25.740         0     no  southeast   3756.62160
# ...

# %%
ins.rename(columns={'Sex':'Gender'})
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# #SEABORN

# %%
sns.relplot(data=ins,x='charges',y='age',kind='scatter')

# %%
male = ins.query("sex == 'male'")
sns.lineplot(data=ins, x="age", y="children")
# Out:
# <Axes: xlabel='age', ylabel='children'>

# %%
sns.displot(data=ins, x="age")

# %%
sns.displot(data=ins, x="age",kind='kde')

# %%
sns.displot(data=ins, x="age", kde=True)

# %%
sns.histplot(data=ins, x="age")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=ins, y="age")
# Out:
# <Axes: xlabel='Count', ylabel='age'>

# %%
sns.histplot(data=ins, x="age", bins=30)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(data=ins, x="age")
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=ins, y="age")
# Out:
# <Axes: xlabel='Density', ylabel='age'>

# %%
sns.kdeplot(data=ins)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=ins, x="children", hue="sex", multiple="stack")
# Out:
# <Axes: xlabel='children', ylabel='Density'>

# %%
sns.boxplot(x=ins["age"])
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(data=ins, x="sex", y="age", hue="smoker")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x=ins["smoker"])
# Out:
# <Axes: xlabel='smoker'>

# %%
sns.violinplot(data=ins, x="region", y="bmi")
# Out:
# <Axes: xlabel='region', ylabel='bmi'>

# %%
sns.violinplot(data=ins, x="sex", y="bmi", hue="smoker")
# Out:
# <Axes: xlabel='sex', ylabel='bmi'>

# %%
sns.barplot(ins, x="sex", y="charges")
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
sns.barplot(ins, x="sex", y="children", hue="smoker", legend=False)
# Out:
# <Axes: xlabel='sex', ylabel='children'>

# %%
sns.countplot(ins, x="region")
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.countplot(ins, x="region", hue="children")
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.countplot(ins, x="smoker", hue="children", stat="percent")
# Out:
# <Axes: xlabel='smoker', ylabel='percent'>

# %%
ins.drop_duplicates(subset=['age'])
# Out:
#      age     sex     bmi  children smoker     region      charges
# 0     19  female  27.900         0    yes  southwest  16884.92400
# 1     18    male  33.770         1     no  southeast   1725.55230
# 2     28    male  33.000         3     no  southeast   4449.46200
# 3     33    male  22.705         0     no  northwest  21984.47061
# 4     32    male  28.880         0     no  northwest   3866.85520
# 5     31  female  25.740         0     no  southeast   3756.62160
# 6     46  female  33.440         1     no  southeast   8240.58960
# 7     37  female  27.740         3     no  northwest   7281.50560
# 9     60  female  25.840         0     no  northwest  28923.13692
# 10    25    male  26.220         0     no  northeast   2721.32080
# 11    62  female  26.290         0    yes  southeast  27808.72510
# 12    23    male  34.400         0     no  southwest   1826.84300
# 13    56  female  39.820         0     no  southeast  11090.71780
# ...

# %%
df=ins.pivot_table(index="sex", columns="region", values="charges")
sns.heatmap(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(df, annot=True)
# Out:
# <Axes: xlabel='region', ylabel='sex'>

# %%
sns.pairplot(ins)

# %%
sns.pairplot(ins, hue='sex')
