# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# #CSV

# %%
wine=pd.read_csv(r"C:\Users\Hianshi\Downloads\WineQT.csv")
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
wine.count()
# Out:
# fixed acidity           1143
# volatile acidity        1143
# citric acid             1143
# residual sugar          1143
# chlorides               1143
# free sulfur dioxide     1143
# total sulfur dioxide    1143
# density                 1143
# pH                      1143
# sulphates               1143
# alcohol                 1143
# quality                 1143
# Id                      1143
# dtype: int64

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
wine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# ...

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
wine['chlorides'].value_counts()
# Out:
# chlorides
# 0.080    48
# 0.077    41
# 0.074    38
# 0.084    38
# 0.078    36
#          ..
# 0.222     1
# 0.422     1
# 0.034     1
# 0.387     1
# 0.230     1
# Name: count, Length: 131, dtype: int64

# %%
(wine['chlorides'].value_counts()).sort_values
# Out:
# <bound method Series.sort_values of chlorides
# 0.080    48
# 0.077    41
# 0.074    38
# 0.084    38
# 0.078    36
#          ..
# 0.222     1
# 0.422     1
# 0.034     1
# 0.387     1
# 0.230     1
# Name: count, Length: 131, dtype: int64>

# %%
(wine['chlorides'].value_counts()).sort_values(ascending=False)
# Out:
# chlorides
# 0.080    48
# 0.077    41
# 0.074    38
# 0.084    38
# 0.078    36
#          ..
# 0.190     1
# 0.127     1
# 0.341     1
# 0.332     1
# 0.230     1
# Name: count, Length: 131, dtype: int64

# %%
wine.sort_values(['chlorides'])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 598             6.7              0.28         0.28             2.4      0.012
# 597             6.7              0.28         0.28             2.4      0.012
# 493             5.1              0.47         0.02             1.3      0.034
# 574             9.3              0.37         0.44             1.6      0.038
# 1123            6.4              0.38         0.14             2.2      0.038
# ...             ...               ...          ...             ...        ...
# 538             7.8              0.48         0.68             1.7      0.415
# 490             8.6              0.49         0.51             2.0      0.422
# 75              7.8              0.41         0.68             1.7      0.467
# 103             9.2              0.52         1.00             3.4      0.610
# 182             7.7              0.41         0.76             1.8      0.611
#
# ...

# %%
wine.sort_values(['chlorides','citric acid'])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 597             6.7              0.28         0.28             2.4      0.012
# 598             6.7              0.28         0.28             2.4      0.012
# 493             5.1              0.47         0.02             1.3      0.034
# 1123            6.4              0.38         0.14             2.2      0.038
# 574             9.3              0.37         0.44             1.6      0.038
# ...             ...               ...          ...             ...        ...
# 538             7.8              0.48         0.68             1.7      0.415
# 490             8.6              0.49         0.51             2.0      0.422
# 75              7.8              0.41         0.68             1.7      0.467
# 103             9.2              0.52         1.00             3.4      0.610
# 182             7.7              0.41         0.76             1.8      0.611
#
# ...

# %%
wine.drop_duplicates(subset=['citric acid'])
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4             0.700         0.00             1.9      0.076
# 2              7.8             0.760         0.04             2.3      0.092
# 3             11.2             0.280         0.56             1.9      0.075
# 6              7.9             0.600         0.06             1.6      0.069
# 8              7.8             0.580         0.02             2.0      0.073
# ..             ...               ...          ...             ...        ...
# 361           13.3             0.290         0.75             2.8      0.084
# 423            9.9             0.490         0.58             3.5      0.094
# 428            8.3             0.580         0.13             2.9      0.096
# 453            9.5             0.885         0.27             2.3      0.084
# 532            8.2             0.340         0.38             2.5      0.080
#
# ...

# %%
wine.drop_duplicates(subset=['citric acid','chlorides']).shape
# Out:
# (850, 13)

# %%
categories=wine.groupby('chlorides') 
categories

# %%
len(wine)
# Out:
# 1143

# %%
len(categories)
# Out:
# 131

# %%
categories.size()
# Out:
# chlorides
# 0.012    2
# 0.034    1
# 0.038    2
# 0.039    3
# 0.041    4
#         ..
# 0.415    3
# 0.422    1
# 0.467    1
# 0.610    1
# 0.611    1
# Length: 131, dtype: int64

# %%
categories.first()
# Out:
#            fixed acidity  volatile acidity  citric acid  residual sugar  \
# chlorides
# 0.012                6.7              0.28         0.28             2.4
# 0.034                5.1              0.47         0.02             1.3
# 0.038                9.3              0.37         0.44             1.6
# 0.039                9.7              0.53         0.60             2.0
# 0.041                8.4              0.25         0.39             2.0
# ...                  ...               ...          ...             ...
# 0.415                7.8              0.48         0.68             1.7
# 0.422                8.6              0.49         0.51             2.0
# 0.467                7.8              0.41         0.68             1.7
# 0.610                9.2              0.52         1.00             3.4
# 0.611                7.7              0.41         0.76             1.8
#
#            free sulfur dioxide  total sulfur dioxide  density    pH  \
# chlorides
# ...

# %%
wine.rename(columns={'quality':'ratings'})
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# #SEABORN

# %%
sns.relplot(data=wine,x='citric acid',y='residual sugar',kind='scatter')

# %%
qualt = wine.query("quality == '5'")
sns.lineplot(data=wine, x="quality", y="citric acid")
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
sns.displot(data=wine, x="citric acid")

# %%
sns.displot(data=wine, x="citric acid",kind='kde')

# %%
sns.displot(data=wine, x="quality", kde=True)

# %%
sns.histplot(data=wine, x="quality")
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
sns.histplot(data=wine, y="quality")
# Out:
# <Axes: xlabel='Count', ylabel='quality'>

# %%
sns.histplot(data=wine, x="citric acid", bins=30)
# Out:
# <Axes: xlabel='citric acid', ylabel='Count'>

# %%
sns.kdeplot(data=wine, x="chlorides")
# Out:
# <Axes: xlabel='chlorides', ylabel='Density'>

# %%
sns.kdeplot(data=wine, y="pH")
# Out:
# <Axes: xlabel='Density', ylabel='pH'>

# %%
sns.kdeplot(data=wine)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=wine, x="alcohol", hue="quality", multiple="stack")
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
sns.boxplot(x=wine["quality"])
# Out:
# <Axes: xlabel='quality'>

# %%
sns.boxplot(data=wine, x="total sulfur dioxide", y="residual sugar", hue="quality")
# Out:
# <Axes: xlabel='total sulfur dioxide', ylabel='residual sugar'>

# %%
sns.violinplot(x=wine["quality"])
# Out:
# <Axes: xlabel='quality'>

# %%
sns.violinplot(data=wine, x="quality", y="citric acid")
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
sns.violinplot(data=wine, x="quality", y="volatile acidity", hue="quality")
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
sns.barplot(wine, x="quality", y="citric acid")
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
sns.barplot(wine, x="quality", y="citric acid", hue="quality", legend=False)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
sns.countplot(wine, x="quality")
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
sns.countplot(wine, x="quality", hue="citric acid")
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
sns.countplot(wine, x="quality", hue="sulphates", stat="percent")
# Out:
# <Axes: xlabel='quality', ylabel='percent'>

# %%
wine.drop_duplicates(subset=['citric acid'])
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4             0.700         0.00             1.9      0.076
# 2              7.8             0.760         0.04             2.3      0.092
# 3             11.2             0.280         0.56             1.9      0.075
# 6              7.9             0.600         0.06             1.6      0.069
# 8              7.8             0.580         0.02             2.0      0.073
# ..             ...               ...          ...             ...        ...
# 361           13.3             0.290         0.75             2.8      0.084
# 423            9.9             0.490         0.58             3.5      0.094
# 428            8.3             0.580         0.13             2.9      0.096
# 453            9.5             0.885         0.27             2.3      0.084
# 532            8.2             0.340         0.38             2.5      0.080
#
# ...

# %%
wn=wine.pivot_table(index="sulphates", columns="quality", values="pH")
sns.heatmap(wn)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(wn, annot=True)
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

# %%
sns.pairplot(data=wine)

# %%
sns.pairplot(wine , hue='quality')
