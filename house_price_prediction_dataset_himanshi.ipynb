# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# CSV

# %%
hp=pd.read_csv(r"C:\Users\HP\Downloads\House Price Prediction Dataset.csv")
hp
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# ...

# %%
hp.count()
# Out:
# Id           2000
# Area         2000
# Bedrooms     2000
# Bathrooms    2000
# Floors       2000
# YearBuilt    2000
# Location     2000
# Condition    2000
# Garage       2000
# Price        2000
# dtype: int64

# %%
hp.head
# Out:
# <bound method NDFrame.head of         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
# ...

# %%
hp.tail
# Out:
# <bound method NDFrame.tail of         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
# ...

# %%
hp.describe
# Out:
# <bound method NDFrame.describe of         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
# ...

# %%
hp.info
# Out:
# <bound method DataFrame.info of         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
# ...

# %%
hp['Floors'].value_counts()
# Out:
# Floors
# 2    691
# 1    661
# 3    648
# Name: count, dtype: int64

# %%
(hp['Floors'].value_counts()).sort_values
# Out:
# <bound method Series.sort_values of Floors
# 2    691
# 1    661
# 3    648
# Name: count, dtype: int64>

# %%
(hp['Floors'].value_counts()).sort_values(ascending=False)
# Out:
# Floors
# 2    691
# 1    661
# 3    648
# Name: count, dtype: int64

# %%
hp.sort_values(['YearBuilt'])
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 24      25   689         5          1       3       1900     Urban  Excellent
# 576    577  1960         1          3       2       1900  Downtown  Excellent
# 1927  1928  2049         4          1       1       1900     Rural       Fair
# 754    755  2719         3          2       3       1900     Urban       Good
# 1944  1945  2942         4          2       2       1900  Suburban       Good
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1950  1951  1093         2          1       1       2023  Downtown       Poor
# 598    599  2348         1          4       1       2023     Urban  Excellent
# 1707  1708  2637         2          3       2       2023  Downtown       Fair
# 611    612  4844         1          3       3       2023  Downtown       Poor
# 1753  1754  1468         3          3       1       2023  Downtown  Excellent
#
#      Garage   Price
# ...

# %%
hp.sort_values(['YearBuilt','Floors'])
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 1125  1126  1114         5          3       1       1900  Downtown       Good
# 1872  1873  1633         2          2       1       1900     Urban       Fair
# 1927  1928  2049         4          1       1       1900     Rural       Fair
# 576    577  1960         1          3       2       1900  Downtown  Excellent
# 1230  1231  4765         1          3       2       1900  Suburban       Poor
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1950  1951  1093         2          1       1       2023  Downtown       Poor
# 1035  1036  3469         1          4       2       2023  Suburban       Poor
# 1597  1598  4903         1          3       2       2023     Rural  Excellent
# 1707  1708  2637         2          3       2       2023  Downtown       Fair
# 611    612  4844         1          3       3       2023  Downtown       Poor
#
#      Garage   Price
# ...

# %%
hp.drop_duplicates(subset=['Area'])
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1989  1990   647         5          3       3       1919     Rural  Excellent
# 1990  1991  4827         4          4       1       1959  Suburban       Fair
# 1993  1994   865         4          4       2       2020     Rural       Poor
# 1994  1995  2174         1          1       2       1973  Downtown       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
#
#      Garage   Price
# ...

# %%
hp.drop_duplicates(subset=['Area']).shape
# Out:
# (1622, 10)

# %%
categories=hp.groupby('Floors') 
categories

# %%
len(hp)
# Out:
# 2000

# %%
len(categories)
# Out:
# 3

# %%
categories.size()
# Out:
# Floors
# 1    661
# 2    691
# 3    648
# dtype: int64

# %%
categories.first()
# Out:
#         Id  Area  Bedrooms  Bathrooms  YearBuilt  Location  Condition Garage  \
# Floors
# 1        6  3944         1          2       1906     Urban       Poor     No
# 2        4   966         4          2       1902  Suburban       Fair    Yes
# 3        1  1360         5          4       1970  Downtown  Excellent     No
#
#          Price
# Floors
# 1        93262
# 2       244020
# 3       149919

# %%
hp.rename(columns={'Price':'Money'})
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Money
# ...

# %% [markdown]
# SEABORN

# %%
sns.relplot(data=hp,x='Area',y='Price',kind='scatter')

# %%
bd = hp.query("Bedrooms == '5'")
sns.lineplot(data=hp, x="Floors", y="Bathrooms")
# Out:
# <Axes: xlabel='Floors', ylabel='Bathrooms'>

# %%
sns.displot(data=hp, x="Floors")

# %%
sns.displot(data=hp, x="Floors",kind='kde')

# %%
sns.displot(data=hp, x="Bathrooms", kde=True)

# %%
sns.histplot(data=hp, x="Floors")
# Out:
# <Axes: xlabel='Floors', ylabel='Count'>

# %%
sns.histplot(data=hp, y="Price")
# Out:
# <Axes: xlabel='Count', ylabel='Price'>

# %%
sns.histplot(data=hp, x="Price", bins=30)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.kdeplot(data=hp, x="Bedrooms")
# Out:
# <Axes: xlabel='Bedrooms', ylabel='Density'>

# %%
sns.kdeplot(data=hp, y="Bedrooms")
# Out:
# <Axes: xlabel='Density', ylabel='Bedrooms'>

# %%
sns.kdeplot(data=hp)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=hp, x="Price", hue="Condition", multiple="stack")
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.boxplot(x=hp["Price"])
# Out:
# <Axes: xlabel='Price'>

# %%
sns.boxplot(data=hp, x="Bathrooms", y="Area", hue="Garage")
# Out:
# <Axes: xlabel='Bathrooms', ylabel='Area'>

# %%
sns.violinplot(x=hp["Price"])
# Out:
# <Axes: xlabel='Price'>

# %%
sns.violinplot(data=hp, x="Garage", y="Floors")
# Out:
# <Axes: xlabel='Garage', ylabel='Floors'>

# %%
sns.violinplot(data=hp, x="Floors", y="Bathrooms", hue="Condition")
# Out:
# <Axes: xlabel='Floors', ylabel='Bathrooms'>

# %%
sns.barplot(hp, x="Floors", y="Bedrooms")
# Out:
# <Axes: xlabel='Floors', ylabel='Bedrooms'>

# %%
sns.barplot(hp, x="Bedrooms", y="Bathrooms", hue="Garage", legend=False)
# Out:
# <Axes: xlabel='Bedrooms', ylabel='Bathrooms'>

# %%
sns.countplot(hp, x="Bedrooms")
# Out:
# <Axes: xlabel='Bedrooms', ylabel='count'>

# %%
sns.countplot(hp, x="Floors", hue="Location")
# Out:
# <Axes: xlabel='Floors', ylabel='count'>

# %%
sns.countplot(hp, x="Location", hue="Garage", stat="percent")
# Out:
# <Axes: xlabel='Location', ylabel='percent'>

# %%
hp.drop_duplicates(subset=['Price'])
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# ...

# %%
heat=hp.pivot_table(index="Bedrooms", columns="Bathrooms", values="Price")
sns.heatmap(heat)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(heat, annot=True)
# Out:
# <Axes: xlabel='Bathrooms', ylabel='Bedrooms'>

# %%
sns.pairplot(hp)

# %%
sns.pairplot(hp, hue='Garage')
