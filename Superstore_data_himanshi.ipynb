# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# #CSV

# %%
ss=pd.read_csv(r"C:\Users\Hianshi\Downloads\SampleSuperstore.csv")
ss
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
ss.count()
# Out:
# Ship Mode       9994
# Segment         9994
# Country         9994
# City            9994
# State           9994
# Postal Code     9994
# Region          9994
# Category        9994
# Sub-Category    9994
# Sales           9994
# Quantity        9994
# Discount        9994
# Profit          9994
# dtype: int64

# %%
ss.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
ss.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
ss.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
ss['Sales'].value_counts()
# Out:
# Sales
# 12.960     56
# 19.440     39
# 15.552     39
# 25.920     36
# 10.368     36
#            ..
# 4.240       1
# 319.960     1
# 646.740     1
# 81.940      1
# 243.160     1
# Name: count, Length: 5825, dtype: int64

# %%
(ss['Sales'].value_counts()).sort_values
# Out:
# <bound method Series.sort_values of Sales
# 12.960     56
# 19.440     39
# 15.552     39
# 25.920     36
# 10.368     36
#            ..
# 4.240       1
# 319.960     1
# 646.740     1
# 81.940      1
# 243.160     1
# Name: count, Length: 5825, dtype: int64>

# %%
(ss['Sales'].value_counts()).sort_values(ascending=False)
# Out:
# Sales
# 12.960     56
# 15.552     39
# 19.440     39
# 25.920     36
# 10.368     36
#            ..
# 120.576     1
# 12.280      1
# 2.040       1
# 582.336     1
# 243.160     1
# Name: count, Length: 5825, dtype: int64

# %%
ss.sort_values(['Sales'])
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 4101  Standard Class     Consumer  United States        Houston         Texas
# 9292        Same Day    Corporate  United States           Waco         Texas
# 8658  Standard Class    Corporate  United States        Chicago      Illinois
# 4711        Same Day     Consumer  United States   Philadelphia  Pennsylvania
# 2106        Same Day    Corporate  United States       Mesquite         Texas
# ...              ...          ...            ...            ...           ...
# 4190  Standard Class     Consumer  United States         Newark      Delaware
# 2623     First Class  Home Office  United States  New York City      New York
# 8153     First Class     Consumer  United States        Seattle    Washington
# 6826  Standard Class    Corporate  United States      Lafayette       Indiana
# 2697  Standard Class  Home Office  United States   Jacksonville       Florida
#
# ...

# %%
tip.sort_values(['tip','time'])
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# ..          ...    ...     ...    ...   ...     ...   ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
# [244 rows x 7 columns]

# %%
ss.drop_duplicates(subset=['Discount'])
# Out:
#           Ship Mode      Segment        Country             City  \
# 0      Second Class     Consumer  United States        Henderson
# 3    Standard Class     Consumer  United States  Fort Lauderdale
# 4    Standard Class     Consumer  United States  Fort Lauderdale
# 14   Standard Class  Home Office  United States       Fort Worth
# 23     Second Class     Consumer  United States     Philadelphia
# 27   Standard Class     Consumer  United States     Philadelphia
# 28   Standard Class     Consumer  United States     Philadelphia
# 36      First Class    Corporate  United States       Richardson
# 38   Standard Class  Home Office  United States          Houston
# 57      First Class     Consumer  United States             Troy
# 130     First Class    Corporate  United States         Columbus
# 412  Standard Class     Consumer  United States    San Francisco
#
#             State  Postal Code   Region         Category Sub-Category  \
# ...

# %%
ss.drop_duplicates(subset=['Sales','Discount']).shape
# Out:
# (6323, 13)

# %%
categories=ss.groupby('Category') 
categories

# %%
len(ss)
# Out:
# 9994

# %%
len(categories)
# Out:
# 3

# %%
categories.size()
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# dtype: int64

# %%
categories.first()
# Out:
#                       Ship Mode    Segment        Country         City  \
# Category
# Furniture          Second Class   Consumer  United States    Henderson
# Office Supplies    Second Class  Corporate  United States  Los Angeles
# Technology       Standard Class   Consumer  United States  Los Angeles
#
#                       State  Postal Code Region Sub-Category    Sales  \
# Category
# Furniture          Kentucky        42420  South    Bookcases  261.960
# Office Supplies  California        90036   West       Labels   14.620
# Technology       California        90032   West       Phones  907.152
#
#                  Quantity  Discount   Profit
# Category
# Furniture               2       0.0  41.9136
# Office Supplies         2       0.0   6.8714
# Technology              6       0.2  90.7152

# %%
ss.rename(columns={'Ship mode':'Transport class'})
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# #SEABORN

# %%
sns.relplot(data=ss,x='Sales',y='Profit',kind='scatter')

# %%
region = ss.query("Region == 'Sounth'")
sns.lineplot(data=ss, x="Discount", y="Profit")
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
sns.displot(data=ss, x="Category")

# %%
sns.displot(data=ss, x="Quantity",kind='kde')

# %%
sns.displot(data=ss, x="Region", kde=True)

# %%
sns.histplot(data=ss, x="Quantity")
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
sns.histplot(data=ss, y="Discount")
# Out:
# <Axes: xlabel='Count', ylabel='Discount'>

# %%
sns.histplot(data=ss, x="Discount", bins=30)
# Out:
# <Axes: xlabel='Discount', ylabel='Count'>

# %%
sns.kdeplot(data=ss, x="Quantity")
# Out:
# <Axes: xlabel='Quantity', ylabel='Density'>

# %%
sns.kdeplot(data=ss, y="Discount")
# Out:
# <Axes: xlabel='Density', ylabel='Discount'>

# %%
sns.kdeplot(data=ss)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=ss, x="Discount", hue="Ship Mode", multiple="stack")
# Out:
# <Axes: xlabel='Discount', ylabel='Density'>

# %%
sns.boxplot(x=ss["Discount"])
# Out:
# <Axes: xlabel='Discount'>

# %%
sns.boxplot(data=ss, x="Region", y="Quantity", hue="Ship Mode")
# Out:
# <Axes: xlabel='Region', ylabel='Quantity'>

# %%
sns.violinplot(x=ss["Segment"])
# Out:
# <Axes: xlabel='Segment'>

# %%
sns.violinplot(data=ss, x="Segment", y="Region")
# Out:
# <Axes: xlabel='Segment', ylabel='Region'>

# %%
sns.violinplot(data=ss, x="Region", y="Discount", hue="Region")
# Out:
# <Axes: xlabel='Region', ylabel='Discount'>

# %%
sns.barplot(ss, x="Ship Mode", y="Discount")
# Out:
# <Axes: xlabel='Ship Mode', ylabel='Discount'>

# %%
sns.barplot(ss, x="Region", y="Sales", hue="Category", legend=False)
# Out:
# <Axes: xlabel='Region', ylabel='Sales'>

# %%
sns.countplot(ss, x="Category")
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(ss, x="Region", hue="Ship Mode")
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
sns.countplot(ss, x="Category", hue="Region", stat="percent")
# Out:
# <Axes: xlabel='Category', ylabel='percent'>

# %%
ss.drop_duplicates(subset=['Sales'])
# Out:
#            Ship Mode      Segment        Country             City       State  \
# 0       Second Class     Consumer  United States        Henderson    Kentucky
# 1       Second Class     Consumer  United States        Henderson    Kentucky
# 2       Second Class    Corporate  United States      Los Angeles  California
# 3     Standard Class     Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class     Consumer  United States  Fort Lauderdale     Florida
# ...              ...          ...            ...              ...         ...
# 9977  Standard Class  Home Office  United States      Los Angeles  California
# 9978  Standard Class  Home Office  United States      Los Angeles  California
# 9979  Standard Class  Home Office  United States      Los Angeles  California
# 9983  Standard Class     Consumer  United States     Grand Rapids    Michigan
# 9993    Second Class     Consumer  United States      Westminster  California
#
# ...

# %%
heat= ss.pivot_table(index="Discount", columns="Quantity", values="Profit")
sns.heatmap(heat)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(heat, annot=True)
# Out:
# <Axes: xlabel='Quantity', ylabel='Discount'>

# %%
sns.pairplot(data=ss)

# %%
sns.pairplot(ss , hue='Region')
